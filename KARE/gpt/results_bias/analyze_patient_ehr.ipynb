# %%
# Import Required Libraries
import json
import os
# Import the patient analyzer module
from patient_analyzer import PatientAnalyzer

# %% [markdown]
# # Patient EHR Data Analysis - R1

# %% [markdown]
# ## 74955_2

# %% [markdown]
# - "label": 1
# - condition A:   "mortality_probability": 0.55, "survival_probability": 0.45,
# - condition B:   "mortality_probability": 0.4, "survival_probability": 0.6,

# %%
# Define file path - update this to your patient JSON file
file_path = "/data/wang/junh/githubs/Debate/KARE/gpt/results/filtered_patient_ids/R1/74955_2_data.json"

# Load JSON data
with open(file_path, 'r') as f:
    patient_data = json.load(f)

print(f"Loaded data for patient: {patient_data['patient_id']}")
# Out:
# Loaded data for patient: 74955_2

# %%
# Create analyzer instance
analyzer = PatientAnalyzer()

# Analyze the patient with all features
# Set show_predictions=True and provide log_path to see model predictions
# Set show_next_visit_icd=True to see ICD-9 codes for the next visit
analyzer.analyze_patient(
    patient_data=patient_data,
    log_path="/data/wang/junh/githubs/Debate/KARE/gpt/results/condition_A_gpt_4o",
    show_predictions=True,
    show_next_visit_icd=True
)
# Out:
# ================================================================================
# PATIENT ANALYSIS: 74955_2
# ================================================================================
#
# GROUND TRUTH LABEL
# --------------------------------------------------------------------------------
# Label: 1 (MORTALITY)
#
# CONCEPT COUNTS PER VISIT
# --------------------------------------------------------------------------------
# Visit 0:
#   - Conditions:   14 concepts
#   - Procedures:    5 concepts
#   - Drugs:        67 concepts
#   - Total:        86 concepts
#
# Visit 1:
#   - Conditions:   19 concepts
#   - Procedures:    7 concepts
#   - Drugs:        68 concepts
#   - Total:        94 concepts
#
# Visit 2:
#   - Conditions:   15 concepts
#   - Procedures:    1 concepts
#   - Drugs:        19 concepts
#   - Total:        35 concepts
#
# OVERALL SUMMARY
# ================================================================================
# Patient ID:           74955_2
# Ground Truth Label:   1 (MORTALITY)
# Total Visits:         3
# Total Conditions:     48
# Total Procedures:     13
# Total Drugs:          154
# Total Concepts:       215
# Average per Visit:    71.7 concepts
# ================================================================================
#
# Patient 74955_2 not found in results
#
# NEXT VISIT ICD-9 DIAGNOSIS CODES (PREDICTION TARGET)
# ================================================================================
# Current visit (input): Visit 2
# Prediction target:     Visit 3
#
# Loading MIMIC-III data for Subject ID: 74955...
# --------------------------------------------------------------------------------
# Hospital Admission ID: 100320
# Admission Date:        2201-04-30 07:15:00
# Number of diagnoses:   16
# --------------------------------------------------------------------------------
#
# Seq   ICD-9 Raw  ICD-9 Fmt   CCS    CCS Category Description
# --------------------------------------------------------------------------------
# 1     1518       151.8       13     Cancer of stomach
# 2     56983      569.83      155    Other gastrointestinal disorders
# 3     5781       578.1       153    Gastrointestinal hemorrhage
# 4     2851       285.1       60     Acute posthemorrhagic anemia
# 5     5695       569.5       148    Peritonitis and intestinal abscess
# 6     2724       272.4       53     Disorders of lipid metabolism
# 7     5680       568.0       155    Other gastrointestinal disorders
# 8     55090      550.90      143    Abdominal hernia
# 9     60000      600.00      164    Hyperplasia of prostate
# 10    4019       401.9       98     Essential hypertension
# 11    412        412         101    Coronary atherosclerosis and other heart disease
# 12    V4581      V45.81      101    Coronary atherosclerosis and other heart disease
# 13    V1272      V12.72      47     Other and unspecified benign neoplasm
# 14    V1254      V12.54      117    Other circulatory disease
# 15    V1582      V15.82      663    Screening and history of mental health and substance abuse codes
# 16    V4986      V49.86      259    Residual codes; unclassified
# --------------------------------------------------------------------------------
#
# Unique CCS Categories in Visit 3: 14
#
#   • abdominal hernia
#   • acute posthemorrhagic anemia
#   • cancer of stomach
#   • coronary atherosclerosis and other heart disease
#   • disorders of lipid metabolism
#   • essential hypertension
#   • gastrointestinal hemorrhage
#   • hyperplasia of prostate
#   • other and unspecified benign neoplasm
#   • other circulatory disease
#   • other gastrointestinal disorders
#   • peritonitis and intestinal abscess
#   • residual codes; unclassified
#   • screening and history of mental health and substance abuse codes

# %% [markdown]
# - Query Quality
#     - mortality prognosis in patients with cancer, renal failure, and cardiac conditions
#     - Appropriateness: Medium. It targets three high-yield risk domains present in this patient (GI malignancy, acute renal failure, significant cardiac disease).
#     - Clinically, what this query tends to do: It invites retrieval of generic prognosis statements about multimorbidity rather than context-specific prognostic evidence for a patient with recent mechanical ventilation, AKI, complex postoperative status, and major cardiac interventions.

# %% [markdown]
# - Condition A's analyst
#     - Relevance: Low. They do not contain the patient’s key risk interactions (ventilation, AKI severity, CHF/valve surgery/extracorporeal support, delirium, post-op peritonitis/abscess), and they do not clearly speak to mortality prognosis for the documented clinical scenario.
#
#     - Prognostic signal: Very weak. These are definitions/medication considerations and surveillance comments, not mortality-relevant prognostic evidence.
#
#     - Polarity: Mostly neutral (not overtly “good prognosis” or “poor prognosis”), but can still be harmful by creating false reassurance (benign outpatient-style content) or simply wasting retrieval bandwidth.
#
#     - Contradiction / noise: Severe noise relative to the intended clinical question. This stream suggests the retriever is not well-constrained by acuity/setting and is drifting into GI physiology/pharmacology trivia.

# %% [markdown]
# - Condition A's integrator
#     - Relevance: (MedCorp) — they address mortality/prognosis in cancer + renal failure + cardiac disease in a general sense. (UMLS) — appear to be terminology/translation artifacts (“failure biologic function” with Arabic strings) and do not provide clinical prognostic evidence.
#     - Prognostic signal: (same as relevance)
#     - Polarity: The first retrieved doc contains “<10% survival after IHCA”

# %% [markdown]
# - Condition B (Qwen retriever) has no query

# %% [markdown]
# ## 88432_0

# %% [markdown]
# - "label": 1
# - condition A:   "mortality_probability": 0.6, "survival_probability": 0.4,
# - condition B:   "mortality_probability": 0.3, "survival_probability": 0.7,

# %%
# Define file path - update this to your patient JSON file
file_path = "/data/wang/junh/githubs/Debate/KARE/gpt/results/filtered_patient_ids/R1/88432_0_data.json"

# Load JSON data
with open(file_path, 'r') as f:
    patient_data = json.load(f)

print(f"Loaded data for patient: {patient_data['patient_id']}")
# Out:
# Loaded data for patient: 88432_0

# %%
# Create analyzer instance
analyzer = PatientAnalyzer()

# Analyze the patient with all features
# Set show_predictions=True and provide log_path to see model predictions
# Set show_next_visit_icd=True to see ICD-9 codes for the next visit
analyzer.analyze_patient(
    patient_data=patient_data,
    log_path="/data/wang/junh/githubs/Debate/KARE/gpt/results/condition_A_gpt_4o",
    show_predictions=True,
    show_next_visit_icd=True
)
# Out:
# ================================================================================
# PATIENT ANALYSIS: 88432_0
# ================================================================================
#
# GROUND TRUTH LABEL
# --------------------------------------------------------------------------------
# Label: 1 (MORTALITY)
#
# CONCEPT COUNTS PER VISIT
# --------------------------------------------------------------------------------
# Visit 0:
#   - Conditions:    9 concepts
#   - Procedures:    6 concepts
#   - Drugs:        70 concepts
#   - Total:        85 concepts
#
# OVERALL SUMMARY
# ================================================================================
# Patient ID:           88432_0
# Ground Truth Label:   1 (MORTALITY)
# Total Visits:         1
# Total Conditions:     9
# Total Procedures:     6
# Total Drugs:          70
# Total Concepts:       85
# Average per Visit:    85.0 concepts
# ================================================================================
#
# Patient 88432_0 not found in results
#
# NEXT VISIT ICD-9 DIAGNOSIS CODES (PREDICTION TARGET)
# ================================================================================
# Current visit (input): Visit 0
# Prediction target:     Visit 1
#
# Loading MIMIC-III data for Subject ID: 88432...
# --------------------------------------------------------------------------------
# Hospital Admission ID: 185652
# Admission Date:        2186-07-06 07:15:00
# Number of diagnoses:   4
# --------------------------------------------------------------------------------
#
# Seq   ICD-9 Raw  ICD-9 Fmt   CCS    CCS Category Description
# --------------------------------------------------------------------------------
# 1     1749       174.9       24     Cancer of breast
# 2     1963       196.3       42     Secondary malignancies
# 3     4019       401.9       98     Essential hypertension
# 4     2724       272.4       53     Disorders of lipid metabolism
# --------------------------------------------------------------------------------
#
# Unique CCS Categories in Visit 1: 4
#
#   • cancer of breast
#   • disorders of lipid metabolism
#   • essential hypertension
#   • secondary malignancies

# %% [markdown]
# - Query Quality
#     - prognosis secondary malignancies meningitis elderly
#     - Appropriateness: Medium–High. It directly targets two major EHR condition clusters: secondary malignancies and meningitis.
#     - the query is clinically plausible but incomplete for ICU-level prognosis and can bias retrieval toward an oncology-specific interpretation of meningitis.

# %% [markdown]
# - Condition A's analyst
#     - Relevance: Low. The analyst snippets are largely pharmacy/medication taxonomy and calculation content (e.g., thiazide–calcium retention, pharmacy measurement systems, topical corticosteroids, vitamins). Only one snippet mentions avoiding magnesium products in “kidney failure,” which is not a stated anchor in this patient’s compact EHR.
#     - Prognostic signal: Very weak. These snippets are definitions, drug-class descriptions, or medication cautions—they do not contain mortality rates, severity cues for meningitis, predictors in ventilated patients, or cancer/ICU outcome evidence.

# %% [markdown]
# - Condition A's integrator
#     - Relevance: Medium. (Mecorp is prognostic, UMLS is not)
#     - Prognostic signal: Strong. Rank 1 doc: “The median time of survival is 2 to 4 months, even with treatment.”

# %% [markdown]
# # Patient EHR Data Analysis - R2

# %% [markdown]
# ## 188_0

# %%
# Define file path - update this to your patient JSON file
file_path = "/data/wang/junh/githubs/Debate/KARE/gpt/results/filtered_patient_ids/R2/188_0_data.json"

# Load JSON data
with open(file_path, 'r') as f:
    patient_data = json.load(f)

print(f"Loaded data for patient: {patient_data['patient_id']}")
analyzer.analyze_patient(
    patient_data=patient_data,
    log_path="/data/wang/junh/githubs/Debate/KARE/gpt/results/condition_B_gpt_4o",
    show_predictions=True,
    show_next_visit_icd=True
)
# Out:
# Loaded data for patient: 188_0
# ================================================================================
# PATIENT ANALYSIS: 188_0
# ================================================================================
#
# GROUND TRUTH LABEL
# --------------------------------------------------------------------------------
# Label: 1 (MORTALITY)
#
# CONCEPT COUNTS PER VISIT
# --------------------------------------------------------------------------------
# Visit 0:
#   - Conditions:   16 concepts
#   - Procedures:    3 concepts
#   - Drugs:        73 concepts
#   - Total:        92 concepts
#
# OVERALL SUMMARY
# ================================================================================
# Patient ID:           188_0
# Ground Truth Label:   1 (MORTALITY)
# Total Visits:         1
# Total Conditions:     16
# Total Procedures:     3
# Total Drugs:          73
# Total Concepts:       92
# Average per Visit:    92.0 concepts
# ================================================================================
#
# Patient 188_0 not found in results
#
# NEXT VISIT ICD-9 DIAGNOSIS CODES (PREDICTION TARGET)
# ================================================================================
# Current visit (input): Visit 0
# Prediction target:     Visit 1
#
# Loading MIMIC-III data for Subject ID: 188...
# --------------------------------------------------------------------------------
# Hospital Admission ID: 160697
# Admission Date:        2157-01-11 16:56:00
# Number of diagnoses:   5
# --------------------------------------------------------------------------------
#
# Seq   ICD-9 Raw  ICD-9 Fmt   CCS    CCS Category Description
# --------------------------------------------------------------------------------
# 1     570        570         151    Other liver diseases
# 2     07054      070.54      6      Hepatitis
# 3     1552       155.2       16     Cancer of liver and intrahepatic bile duct
# 4     5723       572.3       151    Other liver diseases
# 5     78071      780.71      252    Malaise and fatigue
# --------------------------------------------------------------------------------
#
# Unique CCS Categories in Visit 1: 4
#
#   • cancer of liver and intrahepatic bile duct
#   • hepatitis
#   • malaise and fatigue
#   • other liver diseases

# %% [markdown]
# ## 4406_0

# %%
# Define file path - update this to your patient JSON file
file_path = "/data/wang/junh/githubs/Debate/KARE/gpt/results/filtered_patient_ids/R2/4406_0_data.json"

# Load JSON data
with open(file_path, 'r') as f:
    patient_data = json.load(f)

print(f"Loaded data for patient: {patient_data['patient_id']}")
analyzer.analyze_patient(
    patient_data=patient_data,
    log_path="/data/wang/junh/githubs/Debate/KARE/gpt/results/condition_B_gpt_4o",
    show_predictions=True,
    show_next_visit_icd=True
)
# Out:
# Loaded data for patient: 4406_0
# ================================================================================
# PATIENT ANALYSIS: 4406_0
# ================================================================================
#
# GROUND TRUTH LABEL
# --------------------------------------------------------------------------------
# Label: 1 (MORTALITY)
#
# CONCEPT COUNTS PER VISIT
# --------------------------------------------------------------------------------
# Visit 0:
#   - Conditions:    9 concepts
#   - Procedures:    4 concepts
#   - Drugs:        42 concepts
#   - Total:        55 concepts
#
# OVERALL SUMMARY
# ================================================================================
# Patient ID:           4406_0
# Ground Truth Label:   1 (MORTALITY)
# Total Visits:         1
# Total Conditions:     9
# Total Procedures:     4
# Total Drugs:          42
# Total Concepts:       55
# Average per Visit:    55.0 concepts
# ================================================================================
#
# Patient 4406_0 not found in results
#
# NEXT VISIT ICD-9 DIAGNOSIS CODES (PREDICTION TARGET)
# ================================================================================
# Current visit (input): Visit 0
# Prediction target:     Visit 1
#
# Loading MIMIC-III data for Subject ID: 4406...
# --------------------------------------------------------------------------------
# Hospital Admission ID: 171510
# Admission Date:        2170-01-26 10:50:00
# Number of diagnoses:   9
# --------------------------------------------------------------------------------
#
# Seq   ICD-9 Raw  ICD-9 Fmt   CCS    CCS Category Description
# --------------------------------------------------------------------------------
# 1     5570       557.0       114    Peripheral and visceral atherosclerosis
# 2     4280       428.0       108    Congestive heart failure; nonhypertensive
# 3     4275       427.5       107    Cardiac arrest and ventricular fibrillation
# 4     42731      427.31      106    Cardiac dysrhythmias
# 5     78039      780.39      83     Epilepsy; convulsions
# 6     5990       599.0       159    Urinary tract infections
# 7     7907       790.7       2      Septicemia (except in labor)
# 8     5849       584.9       157    Acute and unspecified renal failure
# 9     2851       285.1       60     Acute posthemorrhagic anemia
# --------------------------------------------------------------------------------
#
# Unique CCS Categories in Visit 1: 9
#
#   • acute and unspecified renal failure
#   • acute posthemorrhagic anemia
#   • cardiac arrest and ventricular fibrillation
#   • cardiac dysrhythmias
#   • congestive heart failure; nonhypertensive
#   • epilepsy; convulsions
#   • peripheral and visceral atherosclerosis
#   • septicemia (except in labor)
#   • urinary tract infections

# %% [markdown]
# ## 9787_0

# %%
# Define file path - update this to your patient JSON file
file_path = "/data/wang/junh/githubs/Debate/KARE/gpt/results/filtered_patient_ids/R2/9787_0_data.json"

# Load JSON data
with open(file_path, 'r') as f:
    patient_data = json.load(f)

print(f"Loaded data for patient: {patient_data['patient_id']}")
analyzer.analyze_patient(
    patient_data=patient_data,
    log_path="/data/wang/junh/githubs/Debate/KARE/gpt/results/condition_B_gpt_4o",
    show_predictions=True,
    show_next_visit_icd=True
)
# Out:
# Loaded data for patient: 9787_0
# ================================================================================
# PATIENT ANALYSIS: 9787_0
# ================================================================================
#
# GROUND TRUTH LABEL
# --------------------------------------------------------------------------------
# Label: 1 (MORTALITY)
#
# CONCEPT COUNTS PER VISIT
# --------------------------------------------------------------------------------
# Visit 0:
#   - Conditions:    8 concepts
#   - Procedures:    2 concepts
#   - Drugs:        24 concepts
#   - Total:        34 concepts
#
# OVERALL SUMMARY
# ================================================================================
# Patient ID:           9787_0
# Ground Truth Label:   1 (MORTALITY)
# Total Visits:         1
# Total Conditions:     8
# Total Procedures:     2
# Total Drugs:          24
# Total Concepts:       34
# Average per Visit:    34.0 concepts
# ================================================================================
#
# Patient 9787_0 not found in results
#
# NEXT VISIT ICD-9 DIAGNOSIS CODES (PREDICTION TARGET)
# ================================================================================
# Current visit (input): Visit 0
# Prediction target:     Visit 1
#
# Loading MIMIC-III data for Subject ID: 9787...
# --------------------------------------------------------------------------------
# Hospital Admission ID: 101908
# Admission Date:        2106-05-06 16:52:00
# Number of diagnoses:   8
# --------------------------------------------------------------------------------
#
# Seq   ICD-9 Raw  ICD-9 Fmt   CCS    CCS Category Description
# --------------------------------------------------------------------------------
# 1     51882      518.82      131    Respiratory failure; insufficiency; arrest (adult)
# 2     7907       790.7       2      Septicemia (except in labor)
# 3     481        481         122    Pneumonia
# 4     1970       197.0       42     Secondary malignancies
# 5     5849       584.9       157    Acute and unspecified renal failure
# 6     0412       041.2       3      Bacterial infection; unspecified site
# 7     5191       519.1       134    Other upper respiratory disease
# 8     4019       401.9       98     Essential hypertension
# --------------------------------------------------------------------------------
#
# Unique CCS Categories in Visit 1: 8
#
#   • acute and unspecified renal failure
#   • bacterial infection; unspecified site
#   • essential hypertension
#   • other upper respiratory disease
#   • pneumonia
#   • respiratory failure; insufficiency; arrest (adult)
#   • secondary malignancies
#   • septicemia (except in labor)

# %% [markdown]
# ## 25578_0

# %%
# Define file path - update this to your patient JSON file
file_path = "/data/wang/junh/githubs/Debate/KARE/gpt/results/filtered_patient_ids/R2/25578_0_data.json"

# Load JSON data
with open(file_path, 'r') as f:
    patient_data = json.load(f)

print(f"Loaded data for patient: {patient_data['patient_id']}")

analyzer.analyze_patient(
    patient_data=patient_data,
    log_path="/data/wang/junh/githubs/Debate/KARE/gpt/results/condition_B_gpt_4o",
    show_predictions=True,
    show_next_visit_icd=True
)
# Out:
# Loaded data for patient: 25578_0
# ================================================================================
# PATIENT ANALYSIS: 25578_0
# ================================================================================
#
# GROUND TRUTH LABEL
# --------------------------------------------------------------------------------
# Label: 1 (MORTALITY)
#
# CONCEPT COUNTS PER VISIT
# --------------------------------------------------------------------------------
# Visit 0:
#   - Conditions:   26 concepts
#   - Procedures:    3 concepts
#   - Drugs:        22 concepts
#   - Total:        51 concepts
#
# OVERALL SUMMARY
# ================================================================================
# Patient ID:           25578_0
# Ground Truth Label:   1 (MORTALITY)
# Total Visits:         1
# Total Conditions:     26
# Total Procedures:     3
# Total Drugs:          22
# Total Concepts:       51
# Average per Visit:    51.0 concepts
# ================================================================================
#
# Patient 25578_0 not found in results
#
# NEXT VISIT ICD-9 DIAGNOSIS CODES (PREDICTION TARGET)
# ================================================================================
# Current visit (input): Visit 0
# Prediction target:     Visit 1
#
# Loading MIMIC-III data for Subject ID: 25578...
# --------------------------------------------------------------------------------
# Hospital Admission ID: 153110
# Admission Date:        2185-04-05 03:37:00
# Number of diagnoses:   27
# --------------------------------------------------------------------------------
#
# Seq   ICD-9 Raw  ICD-9 Fmt   CCS    CCS Category Description
# --------------------------------------------------------------------------------
# 1     56985      569.85      155    Other gastrointestinal disorders
# 2     5849       584.9       157    Acute and unspecified renal failure
# 3     2866       286.6       62     Coagulation and hemorrhagic disorders
# 4     5854       585.4       158    Chronic kidney disease
# 5     5990       599.0       159    Urinary tract infections
# 6     58881      588.81      161    Other diseases of kidney and ureters
# 7     2800       280.0       59     Deficiency and other anemia
# 8     2875       287.5       62     Coagulation and hemorrhagic disorders
# 9     40390      403.90      99     Hypertension with complications and secondary hypertension
# 10    0414       041.4       3      Bacterial infection; unspecified site
# 11    42731      427.31      106    Cardiac dysrhythmias
# 12    92411      924.11      239    Superficial injury; contusion
# 13    E8889      E888.9      2603   E Codes: Fall
# 14    79902      799.02      244    Other injuries and conditions due to external causes
# 15    4241       424.1       96     Heart valve disorders
# 16    2948       294.8       653    Delirium
# 17    4168       416.8       103    Pulmonary heart disease
# 18    71536      715.36      203    Osteoarthritis
# 19    2749       274.9       54     Gout and other crystal arthropathies
# 20    2724       272.4       53     Disorders of lipid metabolism
# 21    7963       796.3       259    Residual codes; unclassified
# 22    9080       908.0       234    Crushing injury or internal injury
# 23    7296       729.6       211    Other connective tissue disease
# 24    E989       E989        2619   E Codes: Other specified; NEC
# 25    4556       455.6       120    Hemorrhoids
# 26    V4501      V45.01      105    Conduction disorders
# 27    V1046      V10.46      29     Cancer of prostate
# --------------------------------------------------------------------------------
#
# Unique CCS Categories in Visit 1: 26
#
#   • acute and unspecified renal failure
#   • bacterial infection; unspecified site
#   • cancer of prostate
#   • cardiac dysrhythmias
#   • chronic kidney disease
#   • coagulation and hemorrhagic disorders
#   • conduction disorders
#   • crushing injury or internal injury
#   • deficiency and other anemia
#   • delirium
#   • disorders of lipid metabolism
#   • e codes: fall
#   • e codes: other specified; nec
#   • gout and other crystal arthropathies
#   • heart valve disorders
#   • hemorrhoids
#   • hypertension with complications and secondary hypertension
#   • osteoarthritis
#   • other connective tissue disease
#   • other diseases of kidney and ureters
#   • other gastrointestinal disorders
#   • other injuries and conditions due to external causes
#   • pulmonary heart disease
#   • residual codes; unclassified
#   • superficial injury; contusion
#   • urinary tract infections

# %% [markdown]
# ## 29765_0

# %%
# Define file path - update this to your patient JSON file
file_path = "/data/wang/junh/githubs/Debate/KARE/gpt/results/filtered_patient_ids/R2/29765_0_data.json"

# Load JSON data
with open(file_path, 'r') as f:
    patient_data = json.load(f)

print(f"Loaded data for patient: {patient_data['patient_id']}")

analyzer.analyze_patient(
    patient_data=patient_data,
    log_path="/data/wang/junh/githubs/Debate/KARE/gpt/results/condition_B_gpt_4o",
    show_predictions=True,
    show_next_visit_icd=True
)
# Out:
# Loaded data for patient: 29765_0
# ================================================================================
# PATIENT ANALYSIS: 29765_0
# ================================================================================
#
# GROUND TRUTH LABEL
# --------------------------------------------------------------------------------
# Label: 1 (MORTALITY)
#
# CONCEPT COUNTS PER VISIT
# --------------------------------------------------------------------------------
# Visit 0:
#   - Conditions:   12 concepts
#   - Procedures:    9 concepts
#   - Drugs:        50 concepts
#   - Total:        71 concepts
#
# OVERALL SUMMARY
# ================================================================================
# Patient ID:           29765_0
# Ground Truth Label:   1 (MORTALITY)
# Total Visits:         1
# Total Conditions:     12
# Total Procedures:     9
# Total Drugs:          50
# Total Concepts:       71
# Average per Visit:    71.0 concepts
# ================================================================================
#
# Patient 29765_0 not found in results
#
# NEXT VISIT ICD-9 DIAGNOSIS CODES (PREDICTION TARGET)
# ================================================================================
# Current visit (input): Visit 0
# Prediction target:     Visit 1
#
# Loading MIMIC-III data for Subject ID: 29765...
# --------------------------------------------------------------------------------
# Hospital Admission ID: 173513
# Admission Date:        2166-12-31 18:11:00
# Number of diagnoses:   12
# --------------------------------------------------------------------------------
#
# Seq   ICD-9 Raw  ICD-9 Fmt   CCS    CCS Category Description
# --------------------------------------------------------------------------------
# 1     20500      205.00      39     Leukemias
# 2     51882      518.82      131    Respiratory failure; insufficiency; arrest (adult)
# 3     2841       284.1       59     Deficiency and other anemia
# 4     486        486         122    Pneumonia
# 5     5849       584.9       157    Acute and unspecified renal failure
# 6     7907       790.7       2      Septicemia (except in labor)
# 7     2761       276.1       55     Fluid and electrolyte disorders
# 8     04110      041.10      3      Bacterial infection; unspecified site
# 9     28800      288.00      63     Diseases of white blood cells
# 10    7806       780.6       246    Fever of unknown origin
# 11    3599       359.9       95     Other nervous system disorders
# 12    138        138         78     Other CNS infection and poliomyelitis
# --------------------------------------------------------------------------------
#
# Unique CCS Categories in Visit 1: 12
#
#   • acute and unspecified renal failure
#   • bacterial infection; unspecified site
#   • deficiency and other anemia
#   • diseases of white blood cells
#   • fever of unknown origin
#   • fluid and electrolyte disorders
#   • leukemias
#   • other cns infection and poliomyelitis
#   • other nervous system disorders
#   • pneumonia
#   • respiratory failure; insufficiency; arrest (adult)
#   • septicemia (except in labor)
